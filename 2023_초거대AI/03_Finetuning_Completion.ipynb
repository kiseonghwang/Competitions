# %% [markdown]
# # 초거대 AI Finetuning 실습
#
# ### 경북A1/황기성/러닝머신
#
# * OpenAI 패키지 설치
# * OpenAI 환경 설정
# * GPT Completion 모델 Finetuning

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import os
import openai

api_key = "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"

# Finetuning/langchain 환경 변수 설정 필요

os.environ["OPENAI_API_KEY"] = api_key
openai.api_key = os.getenv("OPENAI_API_KEY")

openai.api_type
# Out:
# 'open_ai'

# %%
# csv -> jsonl 파일로 변환
# !openai tools fine_tunes.prepare_data --file Finetuning_data.csv --quiet
# Out:
# Analyzing...
#
# - Based on your file extension, your file is formatted as a CSV file
# - Your file contains 216 prompt-completion pairs
# - The input file should contain exactly two columns/keys per row. Additional columns/keys present are: ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6']
#   WARNING: Some of the additional columns/keys contain `Unnamed: 2` in their name. These will be ignored, and the column/key `Unnamed: 2` will be used instead. This could also result from a duplicate column/key in the provided file.
#   WARNING: Some of the additional columns/keys contain `Unnamed: 3` in their name. These will be ignored, and the column/key `Unnamed: 3` will be used instead. This could also result from a duplicate column/key in the provided file.
# ...

# %%
# 3. Finetuning 작업 제출!!(파일 업로드, Openai 파인튜닝 작업 라인에 추가, 진행 (약 10분, 금액은 약 $0.5))
! openai api fine_tunes.create -t "Finetuning_data_prepared.jsonl" --model davinci --suffix "hwang0313"
# Out:
# Upload progress: 100% 9.80k/9.80k [00:00<00:00, 13.6Mit/s]
# Uploaded file from Finetuning_data_prepared.jsonl: file-fSYwmKaKHj5RezHmGdi7VZL6
# Created fine-tune: ft-RxXL9YH402mEWAIaSo7XpwXQ
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-09-14 06:40:09] Created fine-tune: ft-RxXL9YH402mEWAIaSo7XpwXQ
# [2023-09-14 06:40:26] Fine-tune costs $0.33
# [2023-09-14 06:40:26] Fine-tune enqueued. Queue number: 0
# [2023-09-14 06:40:28] Fine-tune started

# %%
# 4 Finetuning 모델 확인

openai.FineTune.list()
# Out:
# <OpenAIObject list at 0x7defaa61b010> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine-tune",
#       "id": "ft-VLGHU1p7U0t5ZeIya3YIwxSO",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1
#       },
#       "organization_id": "org-7Lm0xvbSwZUIOfB2K2aT9P2I",
#       "model": "davinci",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-GIfPzFGro4gHqo3byACeCQ72",
#           "purpose": "fine-tune",
#           "filename": "InitialSound_FT_Dataset_prepared.jsonl",
#           "bytes": 11574,
#           "created_at": 1694228784,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-O4AlJ4jNRT9ORVjLyUUWArQv",
#           "purpose": "fine-tune-results",
# ...

# %%
# 5. 모델 사용

response = openai.Completion.create(
    model="davinci:ft-swhub-ai:hwang0313-2023-09-14-06-49-34",
    temperature=0,
    max_tokens=1000,
    stop=["\n"],
    prompt="텀 ->"
)

response.choices[0].text
# Out:
# ' 텀블러'

# %%
response = openai.Completion.create(
    model="text-davinci-003",
    temperature=0,
    max_tokens=1000,
    stop=["\n"],
    prompt="텀 ->"
)

response.choices[0].text
# Out:
# ' 이미지'

# %% [markdown]
# 파인튜닝을 배워보고 직접 실습해 보았는데 파인튜닝을 활용하면 기존 gpt의 문제점 중 하나인 최신 정보에 약하다는 단점과 내가 원하는 분야에 성능이 극대화된 gpt를 만들 수 있다고 생각하였습니다.
